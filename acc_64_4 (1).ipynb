# %% [markdown]
# # Facial Emotion Recognition

# %% [markdown]
# ##  Connect google Drive.
#
# FER2013 dataset.

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %% [markdown]
# ## Import Libraries.

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

import numpy as np
from keras.utils import to_categorical
from sklearn.model_selection import train_test_split

from keras.models import Sequential #Initialise neural network model as a sequential network
from keras.layers import Conv2D #Convolution operation
from keras.layers.normalization import BatchNormalization
from keras.regularizers import l2
from keras.layers import Activation#Applies activation function
from keras.layers import Dropout#Prevents overfitting by randomly converting few outputs to zero
from keras.layers import MaxPooling2D # Maxpooling function
from keras.layers import Flatten # Converting 2D arrays into a 1D linear vector
from keras.layers import Dense # Regular fully connected neural network
from keras import optimizers
from keras.callbacks import ReduceLROnPlateau, EarlyStopping, TensorBoard, ModelCheckpoint
from sklearn.metrics import accuracy_score
# Out:
# Using TensorFlow backend.

# %%
def load_data(dataset_path):
  
  #classes = ['Angry', 'Disgust', 'Fear', 'Happy', 'Sad', 'Surprsie', 'Neutral']  #We will be dealing with seven different types of emotions.

  data = []
  test_data = []
  test_labels = []
  labels =[]

  with open(dataset_path, 'r') as file:
      for line_no, line in enumerate(file.readlines()):
          if 0 < line_no <= 35887:
            curr_class, line, set_type = line.split(',')
            image_data = np.asarray([int(x) for x in line.split()]).reshape(48, 48) #Creating a list out of the string then converting it into a 2-Dimensional numpy array.
            image_data =image_data.astype(np.uint8)/255.0
            
            if (set_type.strip() == 'PrivateTest'):
              
              test_data.append(image_data)
              test_labels.append(curr_class)
            else:
              data.append(image_data)
              labels.append(curr_class)
      
      test_data = np.expand_dims(test_data, -1)
      test_labels = to_categorical(test_labels, num_classes = 7)
      data = np.expand_dims(data, -1)   
      labels = to_categorical(labels, num_classes = 7)
    
      return np.array(data), np.array(labels), np.array(test_data), np.array(test_labels)

# %% [markdown]
# ## Load the data.

# %%
dataset_path = "/content/gdrive/My Drive/Colab Notebooks/fer2013.csv" 
train_data, train_labels, test_data, test_labels = load_data(dataset_path)
#train_data, test_data, train_labels, test_labels = train_test_split(data, labels, test_size = test_size,random_state = seed)

print("Number of images in Training set:", len(train_data))
print("Number of images in Test set:", len(test_data))
# Out:
# Number of images in Training set: 32298
# Number of images in Test set: 3589

# %% [markdown]
# ##  Define and Deploy the neural network.

# %%
epochs = 100
batch_size = 64
learning_rate = 0.001


model = Sequential()
    
model.add(Conv2D(64, (3, 3), activation='relu', input_shape=(48, 48, 1), kernel_regularizer=l2(0.01)))
model.add(Conv2D(64, (3, 3), padding='same',activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2), strides=(2, 2)))
model.add(Dropout(0.5))
    
model.add(Conv2D(128, (3, 3), padding='same', activation='relu'))
model.add(BatchNormalization())
model.add(Conv2D(128, (3, 3), padding='same', activation='relu'))
model.add(BatchNormalization())
model.add(Conv2D(128, (3, 3), padding='same', activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.5))
    
model.add(Conv2D(256, (3, 3), padding='same', activation='relu'))
model.add(BatchNormalization())
model.add(Conv2D(256, (3, 3), padding='same', activation='relu'))
model.add(BatchNormalization())
model.add(Conv2D(256, (3, 3), padding='same', activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.5))
    
model.add(Conv2D(512, (3, 3), padding='same', activation='relu'))
model.add(BatchNormalization())
model.add(Conv2D(512, (3, 3), padding='same', activation='relu'))
model.add(BatchNormalization())
model.add(Conv2D(512, (3, 3), padding='same', activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.5))
    
model.add(Flatten())
model.add(Dense(512, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(256, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(7, activation='softmax'))
adam = optimizers.Adam(lr = learning_rate)
model.compile(optimizer = adam, loss = 'categorical_crossentropy', metrics = ['accuracy'])
    
print(model.summary())

lr_reducer = ReduceLROnPlateau(monitor='val_loss', factor=0.95, patience=3)
early_stopper = EarlyStopping(monitor='val_acc', min_delta=0, patience=6, mode='auto')
checkpointer = ModelCheckpoint('/content/gdrive/My Drive/Colab Notebooks/fer/weights.hd5', monitor='val_loss', verbose=1, save_best_only=True)

model_info=model.fit(
                       train_data,
                      train_labels,
                      epochs = epochs,
                      batch_size = batch_size,
                      validation_split = 0.2,
                      shuffle = True,
                      callbacks=[lr_reducer, checkpointer, early_stopper]
                      )
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 46, 46, 64)        640
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 46, 46, 64)        36928
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 46, 46, 64)        256
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 23, 23, 64)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 23, 23, 64)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 23, 23, 128)       73856
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 23, 23, 128)       512
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 23, 23, 128)       147584
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 23, 23, 128)       512
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 23, 23, 128)       147584
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 23, 23, 128)       512
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 11, 11, 128)       0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 11, 11, 128)       0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 11, 11, 256)       295168
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 11, 11, 256)       1024
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 11, 11, 256)       590080
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 11, 11, 256)       1024
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 11, 11, 256)       590080
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 11, 11, 256)       1024
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 5, 5, 256)         0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 5, 5, 256)         0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 5, 5, 512)         1180160
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 5, 5, 512)         2048
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 5, 5, 512)         2359808
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 5, 5, 512)         2048
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 5, 5, 512)         2359808
# _________________________________________________________________
# batch_normalization_10 (Batc (None, 5, 5, 512)         2048
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 2, 2, 512)         0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 2, 2, 512)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 2048)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               1049088
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 256)               131328
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_5 (Dense)              (None, 7)                 455
# =================================================================
# Total params: 9,014,727
# Trainable params: 9,009,223
# Non-trainable params: 5,504
# _________________________________________________________________
# None
# Train on 25838 samples, validate on 6460 samples
# Epoch 1/100
# 25838/25838 [==============================] - 33s 1ms/step - loss: 2.0946 - accuracy: 0.2001 - val_loss: 1.8647 - val_accuracy: 0.2489
#
# Epoch 00001: val_loss improved from inf to 1.86469, saving model to /content/gdrive/My Drive/Colab Notebooks/fer/weights.hd5
# Epoch 2/100
# 25838/25838 [==============================] - 24s 936us/step - loss: 1.8626 - accuracy: 0.2379 - val_loss: 1.8272 - val_accuracy: 0.2489
#
# Epoch 00002: val_loss improved from 1.86469 to 1.82716, saving model to /content/gdrive/My Drive/Colab Notebooks/fer/weights.hd5
# Epoch 3/100
# 25838/25838 [==============================] - 24s 936us/step - loss: 1.8416 - accuracy: 0.2470 - val_loss: 1.8220 - val_accuracy: 0.2489
#
# Epoch 00003: val_loss improved from 1.82716 to 1.82199, saving model to /content/gdrive/My Drive/Colab Notebooks/fer/weights.hd5
# Epoch 4/100
# 25838/25838 [==============================] - 24s 935us/step - loss: 1.8302 - accuracy: 0.2507 - val_loss: 1.8203 - val_accuracy: 0.2489
#
# Epoch 00004: val_loss improved from 1.82199 to 1.82032, saving model to /content/gdrive/My Drive/Colab Notebooks/fer/weights.hd5
# Epoch 5/100
# 25838/25838 [==============================] - 24s 934us/step - loss: 1.8240 - accuracy: 0.2500 - val_loss: 1.8126 - val_accuracy: 0.2489
#
# Epoch 00005: val_loss improved from 1.82032 to 1.81256, saving model to /content/gdrive/My Drive/Colab Notebooks/fer/weights.hd5
# Epoch 6/100
# 25838/25838 [==============================] - 24s 937us/step - loss: 1.8207 - accuracy: 0.2506 - val_loss: 1.8097 - val_accuracy: 0.2489
#
# Epoch 00006: val_loss improved from 1.81256 to 1.80968, saving model to /content/gdrive/My Drive/Colab Notebooks/fer/weights.hd5
# Epoch 7/100
# 25838/25838 [==============================] - 24s 936us/step - loss: 1.8124 - accuracy: 0.2533 - val_loss: 1.8066 - val_accuracy: 0.2488
#
# Epoch 00007: val_loss improved from 1.80968 to 1.80657, saving model to /content/gdrive/My Drive/Colab Notebooks/fer/weights.hd5
# Epoch 8/100
# 25838/25838 [==============================] - 24s 932us/step - loss: 1.8055 - accuracy: 0.2526 - val_loss: 1.7957 - val_accuracy: 0.2503
#
# Epoch 00008: val_loss improved from 1.80657 to 1.79573, saving model to /content/gdrive/My Drive/Colab Notebooks/fer/weights.hd5
# Epoch 9/100
# 25838/25838 [==============================] - 24s 933us/step - loss: 1.7807 - accuracy: 0.2712 - val_loss: 2.2637 - val_accuracy: 0.1412
#
# Epoch 00009: val_loss did not improve from 1.79573
# Epoch 10/100
# 25838/25838 [==============================] - 24s 934us/step - loss: 1.7431 - accuracy: 0.2882 - val_loss: 1.8105 - val_accuracy: 0.2611
#
# Epoch 00010: val_loss did not improve from 1.79573
# Epoch 11/100
# 25838/25838 [==============================] - 24s 934us/step - loss: 1.7062 - accuracy: 0.3030 - val_loss: 1.8164 - val_accuracy: 0.2590
#
# Epoch 00011: val_loss did not improve from 1.79573
# Epoch 12/100
# 25838/25838 [==============================] - 24s 934us/step - loss: 1.6473 - accuracy: 0.3201 - val_loss: 1.7473 - val_accuracy: 0.2757
#
# Epoch 00012: val_loss improved from 1.79573 to 1.74728, saving model to /content/gdrive/My Drive/Colab Notebooks/fer/weights.hd5
# Epoch 13/100
# 25838/25838 [==============================] - 24s 936us/step - loss: 1.6138 - accuracy: 0.3450 - val_loss: 1.6562 - val_accuracy: 0.3466
#
# Epoch 00013: val_loss improved from 1.74728 to 1.65622, saving model to /content/gdrive/My Drive/Colab Notebooks/fer/weights.hd5
# Epoch 14/100
# 25838/25838 [==============================] - 24s 938us/step - loss: 1.5559 - accuracy: 0.3848 - val_loss: 1.5946 - val_accuracy: 0.3964
#
# Epoch 00014: val_loss improved from 1.65622 to 1.59458, saving model to /content/gdrive/My Drive/Colab Notebooks/fer/weights.hd5
# Epoch 15/100
# 25838/25838 [==============================] - 24s 937us/step - loss: 1.5040 - accuracy: 0.4044 - val_loss: 1.4816 - val_accuracy: 0.4217
#
# Epoch 00015: val_loss improved from 1.59458 to 1.48163, saving model to /content/gdrive/My Drive/Colab Notebooks/fer/weights.hd5
# Epoch 16/100
# 25838/25838 [==============================] - 24s 939us/step - loss: 1.4721 - accuracy: 0.4128 - val_loss: 1.5639 - val_accuracy: 0.3887
#
# Epoch 00016: val_loss did not improve from 1.48163
# Epoch 17/100
# 25838/25838 [==============================] - 24s 934us/step - loss: 1.4485 - accuracy: 0.4219 - val_loss: 1.3701 - val_accuracy: 0.4407
#
# Epoch 00017: val_loss improved from 1.48163 to 1.37014, saving model to /content/gdrive/My Drive/Colab Notebooks/fer/weights.hd5
# Epoch 18/100
# 25838/25838 [==============================] - 24s 938us/step - loss: 1.4296 - accuracy: 0.4286 - val_loss: 1.3993 - val_accuracy: 0.4361
#
# Epoch 00018: val_loss did not improve from 1.37014
# Epoch 19/100
# 25838/25838 [==============================] - 24s 937us/step - loss: 1.4108 - accuracy: 0.4360 - val_loss: 1.4005 - val_accuracy: 0.4426
#
# Epoch 00019: val_loss did not improve from 1.37014
# Epoch 20/100
# 25838/25838 [==============================] - 24s 936us/step - loss: 1.3832 - accuracy: 0.4421 - val_loss: 1.3239 - val_accuracy: 0.4460
#
# Epoch 00020: val_loss improved from 1.37014 to 1.32394, saving model to /content/gdrive/My Drive/Colab Notebooks/fer/weights.hd5
# Epoch 21/100
# 25838/25838 [==============================] - 24s 937us/step - loss: 1.3689 - accuracy: 0.4424 - val_loss: 1.3887 - val_accuracy: 0.4376
#
# Epoch 00021: val_loss did not improve from 1.32394
# Epoch 22/100
# 25838/25838 [==============================] - 24s 934us/step - loss: 1.3592 - accuracy: 0.4507 - val_loss: 1.3883 - val_accuracy: 0.4385
#
# Epoch 00022: val_loss did not improve from 1.32394
# Epoch 23/100
# 25838/25838 [==============================] - 24s 934us/step - loss: 1.3519 - accuracy: 0.4573 - val_loss: 1.3345 - val_accuracy: 0.4669
#
# Epoch 00023: val_loss did not improve from 1.32394
# Epoch 24/100
# 25838/25838 [==============================] - 24s 932us/step - loss: 1.3301 - accuracy: 0.4613 - val_loss: 1.2992 - val_accuracy: 0.4783
#
# Epoch 00024: val_loss improved from 1.32394 to 1.29923, saving model to /content/gdrive/My Drive/Colab Notebooks/fer/weights.hd5
# Epoch 25/100
# 25838/25838 [==============================] - 24s 935us/step - loss: 1.3108 - accuracy: 0.4763 - val_loss: 1.2671 - val_accuracy: 0.4785
#
# Epoch 00025: val_loss improved from 1.29923 to 1.26713, saving model to /content/gdrive/My Drive/Colab Notebooks/fer/weights.hd5
# Epoch 26/100
# 25838/25838 [==============================] - 24s 935us/step - loss: 1.2949 - accuracy: 0.4829 - val_loss: 1.3146 - val_accuracy: 0.4887
#
# Epoch 00026: val_loss did not improve from 1.26713
# Epoch 27/100
# 25838/25838 [==============================] - 24s 933us/step - loss: 1.2746 - accuracy: 0.4973 - val_loss: 1.3164 - val_accuracy: 0.5005
#
# Epoch 00027: val_loss did not improve from 1.26713
# Epoch 28/100
# 25838/25838 [==============================] - 24s 933us/step - loss: 1.2550 - accuracy: 0.5104 - val_loss: 1.2141 - val_accuracy: 0.5350
#
# Epoch 00028: val_loss improved from 1.26713 to 1.21408, saving model to /content/gdrive/My Drive/Colab Notebooks/fer/weights.hd5
# Epoch 29/100
# 25838/25838 [==============================] - 24s 934us/step - loss: 1.2316 - accuracy: 0.5215 - val_loss: 1.3144 - val_accuracy: 0.4954
#
# Epoch 00029: val_loss did not improve from 1.21408
# Epoch 30/100
# 25838/25838 [==============================] - 24s 934us/step - loss: 1.2056 - accuracy: 0.5389 - val_loss: 1.1984 - val_accuracy: 0.5472
#
# Epoch 00030: val_loss improved from 1.21408 to 1.19836, saving model to /content/gdrive/My Drive/Colab Notebooks/fer/weights.hd5
# Epoch 31/100
# 25838/25838 [==============================] - 24s 934us/step - loss: 1.1903 - accuracy: 0.5450 - val_loss: 1.1762 - val_accuracy: 0.5585
#
# Epoch 00031: val_loss improved from 1.19836 to 1.17617, saving model to /content/gdrive/My Drive/Colab Notebooks/fer/weights.hd5
# Epoch 32/100
# 25838/25838 [==============================] - 24s 938us/step - loss: 1.1662 - accuracy: 0.5549 - val_loss: 1.2978 - val_accuracy: 0.5062
#
# Epoch 00032: val_loss did not improve from 1.17617
# Epoch 33/100
# 25838/25838 [==============================] - 24s 932us/step - loss: 1.1444 - accuracy: 0.5643 - val_loss: 1.1803 - val_accuracy: 0.5752
#
# Epoch 00033: val_loss did not improve from 1.17617
# Epoch 34/100
# 25838/25838 [==============================] - 24s 934us/step - loss: 1.1250 - accuracy: 0.5751 - val_loss: 1.1823 - val_accuracy: 0.5746
#
# Epoch 00034: val_loss did not improve from 1.17617
# Epoch 35/100
# 25838/25838 [==============================] - 24s 936us/step - loss: 1.0980 - accuracy: 0.5867 - val_loss: 1.1808 - val_accuracy: 0.5628
#
# Epoch 00035: val_loss did not improve from 1.17617
# Epoch 36/100
# 25838/25838 [==============================] - 24s 930us/step - loss: 1.0864 - accuracy: 0.5935 - val_loss: 1.2142 - val_accuracy: 0.5464
#
# Epoch 00036: val_loss did not improve from 1.17617
# Epoch 37/100
# 25838/25838 [==============================] - 24s 930us/step - loss: 1.0689 - accuracy: 0.6027 - val_loss: 1.1782 - val_accuracy: 0.5663
#
# Epoch 00037: val_loss did not improve from 1.17617
# Epoch 38/100
# 25838/25838 [==============================] - 24s 927us/step - loss: 1.0364 - accuracy: 0.6128 - val_loss: 1.1467 - val_accuracy: 0.5856
#
# Epoch 00038: val_loss improved from 1.17617 to 1.14673, saving model to /content/gdrive/My Drive/Colab Notebooks/fer/weights.hd5
# Epoch 39/100
# 25838/25838 [==============================] - 24s 931us/step - loss: 1.0168 - accuracy: 0.6223 - val_loss: 1.2477 - val_accuracy: 0.5630
#
# Epoch 00039: val_loss did not improve from 1.14673
# Epoch 40/100
# 25838/25838 [==============================] - 24s 928us/step - loss: 0.9972 - accuracy: 0.6310 - val_loss: 1.2114 - val_accuracy: 0.5752
#
# Epoch 00040: val_loss did not improve from 1.14673
# Epoch 41/100
# 25838/25838 [==============================] - 24s 927us/step - loss: 1.0038 - accuracy: 0.6335 - val_loss: 1.2056 - val_accuracy: 0.5706
#
# Epoch 00041: val_loss did not improve from 1.14673
# Epoch 42/100
# 25838/25838 [==============================] - 24s 929us/step - loss: 0.9631 - accuracy: 0.6453 - val_loss: 1.1567 - val_accuracy: 0.6002
#
# Epoch 00042: val_loss did not improve from 1.14673
# Epoch 43/100
# 25838/25838 [==============================] - 24s 929us/step - loss: 0.9367 - accuracy: 0.6600 - val_loss: 1.2147 - val_accuracy: 0.5994
#
# Epoch 00043: val_loss did not improve from 1.14673
# Epoch 44/100
# 25838/25838 [==============================] - 24s 926us/step - loss: 0.9277 - accuracy: 0.6634 - val_loss: 1.2182 - val_accuracy: 0.5728
#
# Epoch 00044: val_loss did not improve from 1.14673
# Epoch 45/100
# 25838/25838 [==============================] - 24s 935us/step - loss: 0.9050 - accuracy: 0.6704 - val_loss: 1.1725 - val_accuracy: 0.6054
#
# Epoch 00045: val_loss did not improve from 1.14673
# Epoch 46/100
# 25838/25838 [==============================] - 24s 932us/step - loss: 0.8774 - accuracy: 0.6859 - val_loss: 1.2413 - val_accuracy: 0.5904
#
# Epoch 00046: val_loss did not improve from 1.14673
# Epoch 47/100
# 25838/25838 [==============================] - 24s 930us/step - loss: 0.8664 - accuracy: 0.6937 - val_loss: 1.1785 - val_accuracy: 0.6108
#
# Epoch 00047: val_loss did not improve from 1.14673
# Epoch 48/100
# 25838/25838 [==============================] - 24s 931us/step - loss: 0.8331 - accuracy: 0.7026 - val_loss: 1.2278 - val_accuracy: 0.6144
#
# Epoch 00048: val_loss did not improve from 1.14673
# Epoch 49/100
# 25838/25838 [==============================] - 24s 931us/step - loss: 0.8239 - accuracy: 0.7025 - val_loss: 1.3365 - val_accuracy: 0.5461
#
# Epoch 00049: val_loss did not improve from 1.14673
# Epoch 50/100
# 25838/25838 [==============================] - 24s 928us/step - loss: 0.8164 - accuracy: 0.7117 - val_loss: 1.2366 - val_accuracy: 0.6046
#
# Epoch 00050: val_loss did not improve from 1.14673
# Epoch 51/100
# 25838/25838 [==============================] - 24s 929us/step - loss: 0.8104 - accuracy: 0.7132 - val_loss: 1.1808 - val_accuracy: 0.6139
#
# Epoch 00051: val_loss did not improve from 1.14673
# Epoch 52/100
# 25838/25838 [==============================] - 24s 928us/step - loss: 0.7687 - accuracy: 0.7256 - val_loss: 1.2554 - val_accuracy: 0.6193
#
# Epoch 00052: val_loss did not improve from 1.14673
# Epoch 53/100
# 25838/25838 [==============================] - 24s 928us/step - loss: 0.7597 - accuracy: 0.7352 - val_loss: 1.2699 - val_accuracy: 0.6300
#
# Epoch 00053: val_loss did not improve from 1.14673
# Epoch 54/100
# 25838/25838 [==============================] - 24s 928us/step - loss: 0.7424 - accuracy: 0.7443 - val_loss: 1.1789 - val_accuracy: 0.6224
#
# Epoch 00054: val_loss did not improve from 1.14673
# Epoch 55/100
# 25838/25838 [==============================] - 24s 929us/step - loss: 0.7168 - accuracy: 0.7479 - val_loss: 1.2809 - val_accuracy: 0.6056
#
# Epoch 00055: val_loss did not improve from 1.14673
# Epoch 56/100
# 25838/25838 [==============================] - 24s 928us/step - loss: 0.6996 - accuracy: 0.7566 - val_loss: 1.3734 - val_accuracy: 0.6153
#
# Epoch 00056: val_loss did not improve from 1.14673
# Epoch 57/100
# 25838/25838 [==============================] - 24s 928us/step - loss: 0.6840 - accuracy: 0.7630 - val_loss: 1.3496 - val_accuracy: 0.6241
#
# Epoch 00057: val_loss did not improve from 1.14673
# Epoch 58/100
# 25838/25838 [==============================] - 24s 932us/step - loss: 0.6692 - accuracy: 0.7677 - val_loss: 1.3595 - val_accuracy: 0.6033
#
# Epoch 00058: val_loss did not improve from 1.14673
# Epoch 59/100
# 25838/25838 [==============================] - 24s 930us/step - loss: 0.6584 - accuracy: 0.7722 - val_loss: 1.3408 - val_accuracy: 0.6289
#
# Epoch 00059: val_loss did not improve from 1.14673
# Epoch 60/100
# 25838/25838 [==============================] - 24s 934us/step - loss: 0.6445 - accuracy: 0.7774 - val_loss: 1.3216 - val_accuracy: 0.6224
#
# Epoch 00060: val_loss did not improve from 1.14673
# Epoch 61/100
# 25838/25838 [==============================] - 24s 931us/step - loss: 0.6236 - accuracy: 0.7852 - val_loss: 1.3811 - val_accuracy: 0.6320
#
# Epoch 00061: val_loss did not improve from 1.14673
# Epoch 62/100
# 25838/25838 [==============================] - 24s 932us/step - loss: 0.6102 - accuracy: 0.7915 - val_loss: 1.5088 - val_accuracy: 0.5943
#
# Epoch 00062: val_loss did not improve from 1.14673
# Epoch 63/100
# 25838/25838 [==============================] - 24s 940us/step - loss: 0.6077 - accuracy: 0.7968 - val_loss: 1.3997 - val_accuracy: 0.6209
#
# Epoch 00063: val_loss did not improve from 1.14673
# Epoch 64/100
# 25838/25838 [==============================] - 24s 938us/step - loss: 0.5871 - accuracy: 0.8020 - val_loss: 1.3532 - val_accuracy: 0.6310
#
# Epoch 00064: val_loss did not improve from 1.14673
# Epoch 65/100
# 25838/25838 [==============================] - 24s 936us/step - loss: 0.5641 - accuracy: 0.8074 - val_loss: 1.4704 - val_accuracy: 0.6217
#
# Epoch 00065: val_loss did not improve from 1.14673
# Epoch 66/100
# 25838/25838 [==============================] - 24s 931us/step - loss: 0.5457 - accuracy: 0.8163 - val_loss: 1.4939 - val_accuracy: 0.6303
#
# Epoch 00066: val_loss did not improve from 1.14673
# Epoch 67/100
# 25838/25838 [==============================] - 24s 932us/step - loss: 0.5397 - accuracy: 0.8189 - val_loss: 1.5164 - val_accuracy: 0.6311
#
# Epoch 00067: val_loss did not improve from 1.14673
# Epoch 68/100
# 25838/25838 [==============================] - 24s 934us/step - loss: 0.5322 - accuracy: 0.8208 - val_loss: 1.5063 - val_accuracy: 0.6364
#
# Epoch 00068: val_loss did not improve from 1.14673
# Epoch 69/100
# 25838/25838 [==============================] - 24s 932us/step - loss: 0.5106 - accuracy: 0.8266 - val_loss: 1.6000 - val_accuracy: 0.6424
#
# Epoch 00069: val_loss did not improve from 1.14673
# Epoch 70/100
# 25838/25838 [==============================] - 24s 935us/step - loss: 0.5002 - accuracy: 0.8338 - val_loss: 1.5720 - val_accuracy: 0.6314
#
# Epoch 00070: val_loss did not improve from 1.14673
# Epoch 71/100
# 25838/25838 [==============================] - 24s 939us/step - loss: 0.4889 - accuracy: 0.8366 - val_loss: 1.6979 - val_accuracy: 0.6268
#
# Epoch 00071: val_loss did not improve from 1.14673
# Epoch 72/100
# 25838/25838 [==============================] - 24s 936us/step - loss: 0.4765 - accuracy: 0.8396 - val_loss: 1.5977 - val_accuracy: 0.6307
#
# Epoch 00072: val_loss did not improve from 1.14673
# Epoch 73/100
# 25838/25838 [==============================] - 24s 940us/step - loss: 0.4561 - accuracy: 0.8472 - val_loss: 1.7941 - val_accuracy: 0.6313
#
# Epoch 00073: val_loss did not improve from 1.14673
# Epoch 74/100
# 25838/25838 [==============================] - 24s 932us/step - loss: 0.4441 - accuracy: 0.8541 - val_loss: 1.6005 - val_accuracy: 0.6262
#
# Epoch 00074: val_loss did not improve from 1.14673
# Epoch 75/100
# 25838/25838 [==============================] - 24s 929us/step - loss: 0.4412 - accuracy: 0.8547 - val_loss: 1.6341 - val_accuracy: 0.6368
#
# Epoch 00075: val_loss did not improve from 1.14673
# Epoch 76/100
# 25838/25838 [==============================] - 24s 929us/step - loss: 0.4280 - accuracy: 0.8605 - val_loss: 1.7899 - val_accuracy: 0.6415
#
# Epoch 00076: val_loss did not improve from 1.14673
# Epoch 77/100
# 25838/25838 [==============================] - 24s 929us/step - loss: 0.4170 - accuracy: 0.8626 - val_loss: 1.8232 - val_accuracy: 0.6334
#
# Epoch 00077: val_loss did not improve from 1.14673
# Epoch 78/100
# 25838/25838 [==============================] - 24s 930us/step - loss: 0.4091 - accuracy: 0.8684 - val_loss: 1.6607 - val_accuracy: 0.6308
#
# Epoch 00078: val_loss did not improve from 1.14673
# Epoch 79/100
# 25838/25838 [==============================] - 24s 932us/step - loss: 0.3971 - accuracy: 0.8722 - val_loss: 1.7141 - val_accuracy: 0.6313
#
# Epoch 00079: val_loss did not improve from 1.14673
# Epoch 80/100
# 25838/25838 [==============================] - 24s 929us/step - loss: 0.3879 - accuracy: 0.8734 - val_loss: 1.8222 - val_accuracy: 0.6378
#
# Epoch 00080: val_loss did not improve from 1.14673
# Epoch 81/100
# 25838/25838 [==============================] - 24s 932us/step - loss: 0.3760 - accuracy: 0.8782 - val_loss: 1.7918 - val_accuracy: 0.6260
#
# Epoch 00081: val_loss did not improve from 1.14673
# Epoch 82/100
# 25838/25838 [==============================] - 24s 932us/step - loss: 0.3664 - accuracy: 0.8806 - val_loss: 1.7794 - val_accuracy: 0.6365
#
# Epoch 00082: val_loss did not improve from 1.14673
# Epoch 83/100
# 25838/25838 [==============================] - 24s 936us/step - loss: 0.3844 - accuracy: 0.8764 - val_loss: 1.7018 - val_accuracy: 0.6337
#
# Epoch 00083: val_loss did not improve from 1.14673
# Epoch 84/100
# 25838/25838 [==============================] - 24s 932us/step - loss: 0.3596 - accuracy: 0.8886 - val_loss: 1.8898 - val_accuracy: 0.6446
#
# Epoch 00084: val_loss did not improve from 1.14673
# Epoch 85/100
# 25838/25838 [==============================] - 24s 929us/step - loss: 0.3513 - accuracy: 0.8899 - val_loss: 1.7856 - val_accuracy: 0.6404
#
# Epoch 00085: val_loss did not improve from 1.14673
# Epoch 86/100
# 25838/25838 [==============================] - 24s 929us/step - loss: 0.3281 - accuracy: 0.8974 - val_loss: 1.9200 - val_accuracy: 0.6399
#
# Epoch 00086: val_loss did not improve from 1.14673
# Epoch 87/100
# 25838/25838 [==============================] - 24s 930us/step - loss: 0.3209 - accuracy: 0.8998 - val_loss: 1.9637 - val_accuracy: 0.6455
#
# Epoch 00087: val_loss did not improve from 1.14673
# Epoch 88/100
# 25838/25838 [==============================] - 24s 929us/step - loss: 0.3146 - accuracy: 0.9003 - val_loss: 2.0629 - val_accuracy: 0.6441
#
# Epoch 00088: val_loss did not improve from 1.14673
# Epoch 89/100
# 25838/25838 [==============================] - 24s 929us/step - loss: 0.3066 - accuracy: 0.9037 - val_loss: 1.9688 - val_accuracy: 0.6466
#
# Epoch 00089: val_loss did not improve from 1.14673
# Epoch 90/100
# 25838/25838 [==============================] - 24s 928us/step - loss: 0.3129 - accuracy: 0.9049 - val_loss: 1.8974 - val_accuracy: 0.6461
#
# Epoch 00090: val_loss did not improve from 1.14673
# Epoch 91/100
# 25838/25838 [==============================] - 24s 927us/step - loss: 0.2926 - accuracy: 0.9100 - val_loss: 1.9888 - val_accuracy: 0.6392
#
# Epoch 00091: val_loss did not improve from 1.14673
# Epoch 92/100
# 25838/25838 [==============================] - 24s 927us/step - loss: 0.2779 - accuracy: 0.9121 - val_loss: 2.1382 - val_accuracy: 0.6398
#
# Epoch 00092: val_loss did not improve from 1.14673
# Epoch 93/100
# 25838/25838 [==============================] - 24s 929us/step - loss: 0.2752 - accuracy: 0.9150 - val_loss: 2.1809 - val_accuracy: 0.6370
#
# Epoch 00093: val_loss did not improve from 1.14673
# Epoch 94/100
# 25838/25838 [==============================] - 24s 930us/step - loss: 0.2708 - accuracy: 0.9179 - val_loss: 2.1750 - val_accuracy: 0.6438
#
# Epoch 00094: val_loss did not improve from 1.14673
# Epoch 95/100
# 25838/25838 [==============================] - 24s 929us/step - loss: 0.2692 - accuracy: 0.9174 - val_loss: 2.0213 - val_accuracy: 0.6406
#
# Epoch 00095: val_loss did not improve from 1.14673
# Epoch 96/100
# 25838/25838 [==============================] - 24s 934us/step - loss: 0.2690 - accuracy: 0.9191 - val_loss: 2.1150 - val_accuracy: 0.6362
#
# Epoch 00096: val_loss did not improve from 1.14673
# Epoch 97/100
# 25838/25838 [==============================] - 24s 930us/step - loss: 0.2430 - accuracy: 0.9241 - val_loss: 2.2675 - val_accuracy: 0.6432
#
# Epoch 00097: val_loss did not improve from 1.14673
# Epoch 98/100
# 25838/25838 [==============================] - 24s 929us/step - loss: 0.2463 - accuracy: 0.9243 - val_loss: 2.1842 - val_accuracy: 0.6443
#
# Epoch 00098: val_loss did not improve from 1.14673
# Epoch 99/100
# 25838/25838 [==============================] - 24s 928us/step - loss: 0.2408 - accuracy: 0.9286 - val_loss: 2.1284 - val_accuracy: 0.6409
#
# Epoch 00099: val_loss did not improve from 1.14673
# Epoch 100/100
# 25838/25838 [==============================] - 24s 927us/step - loss: 0.2369 - accuracy: 0.9269 - val_loss: 2.1356 - val_accuracy: 0.6443
#
# Epoch 00100: val_loss did not improve from 1.14673

# %%
predicted_test_labels = np.argmax(model.predict(test_data), axis=1)
test_labels = np.argmax(test_labels, axis=1)
print ("Accuracy score = ", accuracy_score(test_labels, predicted_test_labels)*100)
# Out:
# Accuracy score =  64.41905823349123

# %%
print("Model accuracy  = ",max(model_info.history['accuracy'])*100)
print("Validation accuracy  = ",max(model_info.history['val_accuracy'])*100)
# Out:
# Model accuracy  =  92.85935163497925
# Validation accuracy  =  64.65944051742554

# %%
import matplotlib.pyplot as plt
plt.plot(model_info.history['accuracy'])
plt.plot(model_info.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %%
import matplotlib.pyplot as plt
plt.plot(model_info.history['loss'])
plt.plot(model_info.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper center')
plt.show()

# %% [markdown]
# ###  Save the model.

# %%
from keras.models import model_from_json
model_json = model.to_json()
with open("/content/gdrive/My Drive/Colab Notebooks/fer/model.json", "w") as json_file:
    json_file.write(model_json)
# serialize weights to HDF5
model.save_weights("/content/gdrive/My Drive/Colab Notebooks/fer/model.h5")
print("Saved model to disk")
# Out:
# Saved model to disk
