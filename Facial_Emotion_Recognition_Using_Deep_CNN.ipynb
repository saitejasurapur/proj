# %% [markdown]
# # Facial Emotion Recognition

# %% [markdown]
# ##  Connect google Drive.
#
# FER2013 dataset.

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %% [markdown]
# ## Import Libraries.

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

import numpy as np
from keras.utils import to_categorical
from sklearn.model_selection import train_test_split

from keras.models import Sequential #Initialise neural network model as a sequential network
from keras.layers import Conv2D #Convolution operation
from keras.layers.normalization import BatchNormalization
from keras.regularizers import l2
from keras.layers import Activation#Applies activation function
from keras.layers import Dropout#Prevents overfitting by randomly converting few outputs to zero
from keras.layers import MaxPooling2D # Maxpooling function
from keras.layers import Flatten # Converting 2D arrays into a 1D linear vector
from keras.layers import Dense # Regular fully connected neural network
from keras import optimizers
from keras.callbacks import ReduceLROnPlateau, EarlyStopping, TensorBoard, ModelCheckpoint
from sklearn.metrics import accuracy_score

# %%
def load_data(dataset_path):
  
  #classes = ['Angry', 'Disgust', 'Fear', 'Happy', 'Sad', 'Surprsie', 'Neutral']  #We will be dealing with seven different types of emotions.

  data = []
  test_data = []
  test_labels = []
  labels =[]

  with open(dataset_path, 'r') as file:
      for line_no, line in enumerate(file.readlines()):
          if 0 < line_no <= 35887:
            curr_class, line, set_type = line.split(',')
            image_data = np.asarray([int(x) for x in line.split()]).reshape(48, 48) #Creating a list out of the string then converting it into a 2-Dimensional numpy array.
            image_data =image_data.astype(np.uint8)/255.0
            
            if (set_type.strip() == 'PrivateTest'):
              
              test_data.append(image_data)
              test_labels.append(curr_class)
            else:
              data.append(image_data)
              labels.append(curr_class)
      
      test_data = np.expand_dims(test_data, -1)
      test_labels = to_categorical(test_labels, num_classes = 7)
      data = np.expand_dims(data, -1)   
      labels = to_categorical(labels, num_classes = 7)
    
      return np.array(data), np.array(labels), np.array(test_data), np.array(test_labels)

# %% [markdown]
# ## Load the data.

# %%
dataset_path = "/content/gdrive/My Drive/Colab Notebooks/fer2013.csv" 
train_data, train_labels, test_data, test_labels = load_data(dataset_path)
#train_data, test_data, train_labels, test_labels = train_test_split(data, labels, test_size = test_size,random_state = seed)

print("Number of images in Training set:", len(train_data))
print("Number of images in Test set:", len(test_data))
# Out:
# Number of images in Training set: 32298
# Number of images in Test set: 3589

# %% [markdown]
# ##  Define and Deploy the neural network.

# %%
epochs = 100
batch_size = 64
learning_rate = 0.001


model = Sequential()
    
model.add(Conv2D(64, (3, 3), activation='relu', input_shape=(48, 48, 1), kernel_regularizer=l2(0.01)))
model.add(Conv2D(64, (3, 3), padding='same',activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2), strides=(2, 2)))
model.add(Dropout(0.5))
    
model.add(Conv2D(128, (3, 3), padding='same', activation='relu'))
model.add(BatchNormalization())
model.add(Conv2D(128, (3, 3), padding='same', activation='relu'))
model.add(BatchNormalization())
model.add(Conv2D(128, (3, 3), padding='same', activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.5))
    
model.add(Conv2D(256, (3, 3), padding='same', activation='relu'))
model.add(BatchNormalization())
model.add(Conv2D(256, (3, 3), padding='same', activation='relu'))
model.add(BatchNormalization())
model.add(Conv2D(256, (3, 3), padding='same', activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.5))
    
model.add(Conv2D(512, (3, 3), padding='same', activation='relu'))
model.add(BatchNormalization())
model.add(Conv2D(512, (3, 3), padding='same', activation='relu'))
model.add(BatchNormalization())
model.add(Conv2D(512, (3, 3), padding='same', activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.5))
    
model.add(Flatten())
model.add(Dense(512, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(256, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(7, activation='softmax'))
adam = optimizers.Adam(lr = learning_rate)
model.compile(optimizer = adam, loss = 'categorical_crossentropy', metrics = ['accuracy'])
    
print(model.summary())

lr_reducer = ReduceLROnPlateau(monitor='val_loss', factor=0.9, patience=3)
early_stopper = EarlyStopping(monitor='val_acc', min_delta=0, patience=6, mode='auto')
checkpointer = ModelCheckpoint('/content/gdrive/My Drive/Colab Notebooks/fer2/weights.hd5', monitor='val_loss', verbose=1, save_best_only=True)

model_info=model.fit(
                       train_data,
                      train_labels,
                      epochs = epochs,
                      batch_size = batch_size,
                      validation_split = 0.2,
                      shuffle = True,
                      callbacks=[lr_reducer, checkpointer, early_stopper]
                      )
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 46, 46, 64)        640
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 46, 46, 64)        36928
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 46, 46, 64)        256
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 23, 23, 64)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 23, 23, 64)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 23, 23, 128)       73856
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 23, 23, 128)       512
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 23, 23, 128)       147584
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 23, 23, 128)       512
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 23, 23, 128)       147584
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 23, 23, 128)       512
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 11, 11, 128)       0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 11, 11, 128)       0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 11, 11, 256)       295168
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 11, 11, 256)       1024
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 11, 11, 256)       590080
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 11, 11, 256)       1024
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 11, 11, 256)       590080
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 11, 11, 256)       1024
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 5, 5, 256)         0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 5, 5, 256)         0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 5, 5, 512)         1180160
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 5, 5, 512)         2048
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 5, 5, 512)         2359808
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 5, 5, 512)         2048
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 5, 5, 512)         2359808
# _________________________________________________________________
# batch_normalization_10 (Batc (None, 5, 5, 512)         2048
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 2, 2, 512)         0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 2, 2, 512)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 2048)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               1049088
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 256)               131328
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_5 (Dense)              (None, 7)                 455
# =================================================================
# Total params: 9,014,727
# Trainable params: 9,009,223
# Non-trainable params: 5,504
# _________________________________________________________________
# None
# Train on 25838 samples, validate on 6460 samples
# Epoch 1/100
# 25838/25838 [==============================] - 34s 1ms/step - loss: 2.0883 - accuracy: 0.2026 - val_loss: 1.8423 - val_accuracy: 0.2489
#
# Epoch 00001: val_loss improved from inf to 1.84226, saving model to /content/gdrive/My Drive/Colab Notebooks/fer2/weights.hd5
# Epoch 2/100
# 25838/25838 [==============================] - 25s 964us/step - loss: 1.8627 - accuracy: 0.2365 - val_loss: 1.8373 - val_accuracy: 0.2489
#
# Epoch 00002: val_loss improved from 1.84226 to 1.83731, saving model to /content/gdrive/My Drive/Colab Notebooks/fer2/weights.hd5
# Epoch 3/100
# 25838/25838 [==============================] - 25s 965us/step - loss: 1.8394 - accuracy: 0.2485 - val_loss: 1.8272 - val_accuracy: 0.2489
#
# Epoch 00003: val_loss improved from 1.83731 to 1.82723, saving model to /content/gdrive/My Drive/Colab Notebooks/fer2/weights.hd5
# Epoch 4/100
# 25838/25838 [==============================] - 24s 946us/step - loss: 1.8261 - accuracy: 0.2507 - val_loss: 1.8144 - val_accuracy: 0.2489
#
# Epoch 00004: val_loss improved from 1.82723 to 1.81439, saving model to /content/gdrive/My Drive/Colab Notebooks/fer2/weights.hd5
# Epoch 5/100
# 25838/25838 [==============================] - 24s 926us/step - loss: 1.8214 - accuracy: 0.2498 - val_loss: 1.8094 - val_accuracy: 0.2489
#
# Epoch 00005: val_loss improved from 1.81439 to 1.80943, saving model to /content/gdrive/My Drive/Colab Notebooks/fer2/weights.hd5
# Epoch 6/100
# 25838/25838 [==============================] - 24s 924us/step - loss: 1.8162 - accuracy: 0.2519 - val_loss: 1.8076 - val_accuracy: 0.2489
#
# Epoch 00006: val_loss improved from 1.80943 to 1.80761, saving model to /content/gdrive/My Drive/Colab Notebooks/fer2/weights.hd5
# Epoch 7/100
# 25838/25838 [==============================] - 24s 923us/step - loss: 1.8108 - accuracy: 0.2519 - val_loss: 1.8035 - val_accuracy: 0.2489
#
# Epoch 00007: val_loss improved from 1.80761 to 1.80354, saving model to /content/gdrive/My Drive/Colab Notebooks/fer2/weights.hd5
# Epoch 8/100
# 25838/25838 [==============================] - 24s 922us/step - loss: 1.8030 - accuracy: 0.2513 - val_loss: 1.8169 - val_accuracy: 0.2489
#
# Epoch 00008: val_loss did not improve from 1.80354
# Epoch 9/100
# 25838/25838 [==============================] - 24s 922us/step - loss: 1.7879 - accuracy: 0.2592 - val_loss: 1.7831 - val_accuracy: 0.2494
#
# Epoch 00009: val_loss improved from 1.80354 to 1.78314, saving model to /content/gdrive/My Drive/Colab Notebooks/fer2/weights.hd5
# Epoch 10/100
# 25838/25838 [==============================] - 24s 923us/step - loss: 1.7583 - accuracy: 0.2770 - val_loss: 1.6877 - val_accuracy: 0.3096
#
# Epoch 00010: val_loss improved from 1.78314 to 1.68768, saving model to /content/gdrive/My Drive/Colab Notebooks/fer2/weights.hd5
# Epoch 11/100
# 25838/25838 [==============================] - 24s 931us/step - loss: 1.7038 - accuracy: 0.3063 - val_loss: 1.6962 - val_accuracy: 0.3073
#
# Epoch 00011: val_loss did not improve from 1.68768
# Epoch 12/100
# 25838/25838 [==============================] - 24s 930us/step - loss: 1.6424 - accuracy: 0.3318 - val_loss: 1.5698 - val_accuracy: 0.3379
#
# Epoch 00012: val_loss improved from 1.68768 to 1.56976, saving model to /content/gdrive/My Drive/Colab Notebooks/fer2/weights.hd5
# Epoch 13/100
# 25838/25838 [==============================] - 24s 941us/step - loss: 1.5926 - accuracy: 0.3635 - val_loss: 1.7094 - val_accuracy: 0.2780
#
# Epoch 00013: val_loss did not improve from 1.56976
# Epoch 14/100
# 25838/25838 [==============================] - 24s 926us/step - loss: 1.5482 - accuracy: 0.3859 - val_loss: 1.5047 - val_accuracy: 0.4042
#
# Epoch 00014: val_loss improved from 1.56976 to 1.50473, saving model to /content/gdrive/My Drive/Colab Notebooks/fer2/weights.hd5
# Epoch 15/100
# 25838/25838 [==============================] - 24s 922us/step - loss: 1.5135 - accuracy: 0.3976 - val_loss: 1.4585 - val_accuracy: 0.3971
#
# Epoch 00015: val_loss improved from 1.50473 to 1.45848, saving model to /content/gdrive/My Drive/Colab Notebooks/fer2/weights.hd5
# Epoch 16/100
# 25838/25838 [==============================] - 24s 935us/step - loss: 1.4850 - accuracy: 0.4107 - val_loss: 1.4312 - val_accuracy: 0.4212
#
# Epoch 00016: val_loss improved from 1.45848 to 1.43120, saving model to /content/gdrive/My Drive/Colab Notebooks/fer2/weights.hd5
# Epoch 17/100
# 25838/25838 [==============================] - 25s 949us/step - loss: 1.4573 - accuracy: 0.4219 - val_loss: 1.3785 - val_accuracy: 0.4421
#
# Epoch 00017: val_loss improved from 1.43120 to 1.37853, saving model to /content/gdrive/My Drive/Colab Notebooks/fer2/weights.hd5
# Epoch 18/100
# 25838/25838 [==============================] - 25s 953us/step - loss: 1.4391 - accuracy: 0.4291 - val_loss: 1.4306 - val_accuracy: 0.4121
#
# Epoch 00018: val_loss did not improve from 1.37853
# Epoch 19/100
# 25838/25838 [==============================] - 25s 953us/step - loss: 1.4180 - accuracy: 0.4282 - val_loss: 1.3878 - val_accuracy: 0.4480
#
# Epoch 00019: val_loss did not improve from 1.37853
# Epoch 20/100
# 25838/25838 [==============================] - 25s 949us/step - loss: 1.4057 - accuracy: 0.4400 - val_loss: 1.3977 - val_accuracy: 0.4396
#
# Epoch 00020: val_loss did not improve from 1.37853
# Epoch 21/100
# 25838/25838 [==============================] - 24s 922us/step - loss: 1.3819 - accuracy: 0.4477 - val_loss: 1.3375 - val_accuracy: 0.4590
#
# Epoch 00021: val_loss improved from 1.37853 to 1.33747, saving model to /content/gdrive/My Drive/Colab Notebooks/fer2/weights.hd5
# Epoch 22/100
# 25838/25838 [==============================] - 24s 921us/step - loss: 1.3603 - accuracy: 0.4499 - val_loss: 1.3627 - val_accuracy: 0.4602
#
# Epoch 00022: val_loss did not improve from 1.33747
# Epoch 23/100
# 25838/25838 [==============================] - 24s 917us/step - loss: 1.3520 - accuracy: 0.4591 - val_loss: 1.3351 - val_accuracy: 0.4551
#
# Epoch 00023: val_loss improved from 1.33747 to 1.33512, saving model to /content/gdrive/My Drive/Colab Notebooks/fer2/weights.hd5
# Epoch 24/100
# 25838/25838 [==============================] - 24s 923us/step - loss: 1.3355 - accuracy: 0.4650 - val_loss: 1.3264 - val_accuracy: 0.4797
#
# Epoch 00024: val_loss improved from 1.33512 to 1.32635, saving model to /content/gdrive/My Drive/Colab Notebooks/fer2/weights.hd5
# Epoch 25/100
# 25838/25838 [==============================] - 24s 919us/step - loss: 1.3143 - accuracy: 0.4798 - val_loss: 1.3782 - val_accuracy: 0.4751
#
# Epoch 00025: val_loss did not improve from 1.32635
# Epoch 26/100
# 25838/25838 [==============================] - 24s 919us/step - loss: 1.2995 - accuracy: 0.4883 - val_loss: 1.2927 - val_accuracy: 0.4941
#
# Epoch 00026: val_loss improved from 1.32635 to 1.29268, saving model to /content/gdrive/My Drive/Colab Notebooks/fer2/weights.hd5
# Epoch 27/100
# 25838/25838 [==============================] - 24s 918us/step - loss: 1.2882 - accuracy: 0.4986 - val_loss: 1.2801 - val_accuracy: 0.4867
#
# Epoch 00027: val_loss improved from 1.29268 to 1.28010, saving model to /content/gdrive/My Drive/Colab Notebooks/fer2/weights.hd5
# Epoch 28/100
# 25838/25838 [==============================] - 24s 917us/step - loss: 1.2663 - accuracy: 0.5055 - val_loss: 1.2845 - val_accuracy: 0.4960
#
# Epoch 00028: val_loss did not improve from 1.28010
# Epoch 29/100
# 25838/25838 [==============================] - 24s 918us/step - loss: 1.2442 - accuracy: 0.5188 - val_loss: 1.1988 - val_accuracy: 0.5460
#
# Epoch 00029: val_loss improved from 1.28010 to 1.19882, saving model to /content/gdrive/My Drive/Colab Notebooks/fer2/weights.hd5
# Epoch 30/100
# 25838/25838 [==============================] - 24s 918us/step - loss: 1.2157 - accuracy: 0.5339 - val_loss: 1.2293 - val_accuracy: 0.5214
#
# Epoch 00030: val_loss did not improve from 1.19882
# Epoch 31/100
# 25838/25838 [==============================] - 24s 915us/step - loss: 1.1966 - accuracy: 0.5405 - val_loss: 1.2388 - val_accuracy: 0.5274
#
# Epoch 00031: val_loss did not improve from 1.19882
# Epoch 32/100
# 25838/25838 [==============================] - 24s 915us/step - loss: 1.1805 - accuracy: 0.5441 - val_loss: 1.2292 - val_accuracy: 0.5412
#
# Epoch 00032: val_loss did not improve from 1.19882
# Epoch 33/100
# 25838/25838 [==============================] - 24s 915us/step - loss: 1.1429 - accuracy: 0.5642 - val_loss: 1.2713 - val_accuracy: 0.5291
#
# Epoch 00033: val_loss did not improve from 1.19882
# Epoch 34/100
# 25838/25838 [==============================] - 24s 913us/step - loss: 1.1350 - accuracy: 0.5704 - val_loss: 1.2078 - val_accuracy: 0.5471
#
# Epoch 00034: val_loss did not improve from 1.19882
# Epoch 35/100
# 25838/25838 [==============================] - 24s 916us/step - loss: 1.1004 - accuracy: 0.5848 - val_loss: 1.1657 - val_accuracy: 0.5616
#
# Epoch 00035: val_loss improved from 1.19882 to 1.16575, saving model to /content/gdrive/My Drive/Colab Notebooks/fer2/weights.hd5
# Epoch 36/100
# 25838/25838 [==============================] - 24s 918us/step - loss: 1.0914 - accuracy: 0.5908 - val_loss: 1.1913 - val_accuracy: 0.5748
#
# Epoch 00036: val_loss did not improve from 1.16575
# Epoch 37/100
# 25838/25838 [==============================] - 24s 918us/step - loss: 1.0693 - accuracy: 0.5966 - val_loss: 1.2206 - val_accuracy: 0.5610
#
# Epoch 00037: val_loss did not improve from 1.16575
# Epoch 38/100
# 25838/25838 [==============================] - 24s 914us/step - loss: 1.0530 - accuracy: 0.6019 - val_loss: 1.2184 - val_accuracy: 0.5502
#
# Epoch 00038: val_loss did not improve from 1.16575
# Epoch 39/100
# 25838/25838 [==============================] - 24s 918us/step - loss: 1.0230 - accuracy: 0.6139 - val_loss: 1.2409 - val_accuracy: 0.5266
#
# Epoch 00039: val_loss did not improve from 1.16575
# Epoch 40/100
# 25838/25838 [==============================] - 24s 914us/step - loss: 1.0181 - accuracy: 0.6230 - val_loss: 1.1719 - val_accuracy: 0.5831
#
# Epoch 00040: val_loss did not improve from 1.16575
# Epoch 41/100
# 25838/25838 [==============================] - 24s 914us/step - loss: 0.9881 - accuracy: 0.6333 - val_loss: 1.1876 - val_accuracy: 0.5692
#
# Epoch 00041: val_loss did not improve from 1.16575
# Epoch 42/100
# 25838/25838 [==============================] - 24s 917us/step - loss: 0.9557 - accuracy: 0.6446 - val_loss: 1.1870 - val_accuracy: 0.5741
#
# Epoch 00042: val_loss did not improve from 1.16575
# Epoch 43/100
# 25838/25838 [==============================] - 24s 915us/step - loss: 0.9328 - accuracy: 0.6523 - val_loss: 1.1450 - val_accuracy: 0.5875
#
# Epoch 00043: val_loss improved from 1.16575 to 1.14498, saving model to /content/gdrive/My Drive/Colab Notebooks/fer2/weights.hd5
# Epoch 44/100
# 25838/25838 [==============================] - 24s 916us/step - loss: 0.9277 - accuracy: 0.6576 - val_loss: 1.1567 - val_accuracy: 0.5898
#
# Epoch 00044: val_loss did not improve from 1.14498
# Epoch 45/100
# 25838/25838 [==============================] - 24s 915us/step - loss: 0.8994 - accuracy: 0.6708 - val_loss: 1.1601 - val_accuracy: 0.6000
#
# Epoch 00045: val_loss did not improve from 1.14498
# Epoch 46/100
# 25838/25838 [==============================] - 24s 915us/step - loss: 0.8989 - accuracy: 0.6728 - val_loss: 1.1419 - val_accuracy: 0.5950
#
# Epoch 00046: val_loss improved from 1.14498 to 1.14191, saving model to /content/gdrive/My Drive/Colab Notebooks/fer2/weights.hd5
# Epoch 47/100
# 25838/25838 [==============================] - 24s 918us/step - loss: 0.8661 - accuracy: 0.6805 - val_loss: 1.1980 - val_accuracy: 0.5964
#
# Epoch 00047: val_loss did not improve from 1.14191
# Epoch 48/100
# 25838/25838 [==============================] - 24s 916us/step - loss: 0.8463 - accuracy: 0.6936 - val_loss: 1.2067 - val_accuracy: 0.6014
#
# Epoch 00048: val_loss did not improve from 1.14191
# Epoch 49/100
# 25838/25838 [==============================] - 24s 919us/step - loss: 0.8428 - accuracy: 0.6983 - val_loss: 1.2111 - val_accuracy: 0.6080
#
# Epoch 00049: val_loss did not improve from 1.14191
# Epoch 50/100
# 25838/25838 [==============================] - 24s 921us/step - loss: 0.8224 - accuracy: 0.7038 - val_loss: 1.2007 - val_accuracy: 0.5910
#
# Epoch 00050: val_loss did not improve from 1.14191
# Epoch 51/100
# 25838/25838 [==============================] - 24s 915us/step - loss: 0.7978 - accuracy: 0.7141 - val_loss: 1.2031 - val_accuracy: 0.6133
#
# Epoch 00051: val_loss did not improve from 1.14191
# Epoch 52/100
# 25838/25838 [==============================] - 24s 918us/step - loss: 0.7779 - accuracy: 0.7210 - val_loss: 1.2547 - val_accuracy: 0.6042
#
# Epoch 00052: val_loss did not improve from 1.14191
# Epoch 53/100
# 25838/25838 [==============================] - 24s 916us/step - loss: 0.7612 - accuracy: 0.7285 - val_loss: 1.1930 - val_accuracy: 0.6102
#
# Epoch 00053: val_loss did not improve from 1.14191
# Epoch 54/100
# 25838/25838 [==============================] - 24s 916us/step - loss: 0.7316 - accuracy: 0.7396 - val_loss: 1.2739 - val_accuracy: 0.6029
#
# Epoch 00054: val_loss did not improve from 1.14191
# Epoch 55/100
# 25838/25838 [==============================] - 24s 915us/step - loss: 0.7197 - accuracy: 0.7440 - val_loss: 1.3544 - val_accuracy: 0.5994
#
# Epoch 00055: val_loss did not improve from 1.14191
# Epoch 56/100
# 25838/25838 [==============================] - 24s 915us/step - loss: 0.6868 - accuracy: 0.7564 - val_loss: 1.3257 - val_accuracy: 0.6190
#
# Epoch 00056: val_loss did not improve from 1.14191
# Epoch 57/100
# 25838/25838 [==============================] - 24s 913us/step - loss: 0.6863 - accuracy: 0.7592 - val_loss: 1.3302 - val_accuracy: 0.6132
#
# Epoch 00057: val_loss did not improve from 1.14191
# Epoch 58/100
# 25838/25838 [==============================] - 24s 914us/step - loss: 0.6683 - accuracy: 0.7697 - val_loss: 1.3480 - val_accuracy: 0.6128
#
# Epoch 00058: val_loss did not improve from 1.14191
# Epoch 59/100
# 25838/25838 [==============================] - 24s 914us/step - loss: 0.6501 - accuracy: 0.7754 - val_loss: 1.3604 - val_accuracy: 0.6138
#
# Epoch 00059: val_loss did not improve from 1.14191
# Epoch 60/100
# 25838/25838 [==============================] - 24s 915us/step - loss: 0.6208 - accuracy: 0.7833 - val_loss: 1.4311 - val_accuracy: 0.6212
#
# Epoch 00060: val_loss did not improve from 1.14191
# Epoch 61/100
# 25838/25838 [==============================] - 24s 914us/step - loss: 0.6262 - accuracy: 0.7858 - val_loss: 1.4122 - val_accuracy: 0.6065
#
# Epoch 00061: val_loss did not improve from 1.14191
# Epoch 62/100
# 25838/25838 [==============================] - 24s 915us/step - loss: 0.6075 - accuracy: 0.7925 - val_loss: 1.4665 - val_accuracy: 0.6243
#
# Epoch 00062: val_loss did not improve from 1.14191
# Epoch 63/100
# 25838/25838 [==============================] - 24s 919us/step - loss: 0.5940 - accuracy: 0.7967 - val_loss: 1.4653 - val_accuracy: 0.6234
#
# Epoch 00063: val_loss did not improve from 1.14191
# Epoch 64/100
# 25838/25838 [==============================] - 24s 914us/step - loss: 0.5727 - accuracy: 0.8049 - val_loss: 1.4703 - val_accuracy: 0.6198
#
# Epoch 00064: val_loss did not improve from 1.14191
# Epoch 65/100
# 25838/25838 [==============================] - 24s 916us/step - loss: 0.5653 - accuracy: 0.8056 - val_loss: 1.4322 - val_accuracy: 0.6279
#
# Epoch 00065: val_loss did not improve from 1.14191
# Epoch 66/100
# 25838/25838 [==============================] - 24s 913us/step - loss: 0.5488 - accuracy: 0.8152 - val_loss: 1.4873 - val_accuracy: 0.6248
#
# Epoch 00066: val_loss did not improve from 1.14191
# Epoch 67/100
# 25838/25838 [==============================] - 24s 913us/step - loss: 0.5400 - accuracy: 0.8174 - val_loss: 1.5258 - val_accuracy: 0.6211
#
# Epoch 00067: val_loss did not improve from 1.14191
# Epoch 68/100
# 25838/25838 [==============================] - 24s 914us/step - loss: 0.5210 - accuracy: 0.8282 - val_loss: 1.4678 - val_accuracy: 0.6193
#
# Epoch 00068: val_loss did not improve from 1.14191
# Epoch 69/100
# 25838/25838 [==============================] - 24s 915us/step - loss: 0.5003 - accuracy: 0.8322 - val_loss: 1.6011 - val_accuracy: 0.6265
#
# Epoch 00069: val_loss did not improve from 1.14191
# Epoch 70/100
# 25838/25838 [==============================] - 24s 915us/step - loss: 0.4991 - accuracy: 0.8344 - val_loss: 1.5735 - val_accuracy: 0.6172
#
# Epoch 00070: val_loss did not improve from 1.14191
# Epoch 71/100
# 25838/25838 [==============================] - 24s 913us/step - loss: 0.4798 - accuracy: 0.8409 - val_loss: 1.6293 - val_accuracy: 0.6271
#
# Epoch 00071: val_loss did not improve from 1.14191
# Epoch 72/100
# 25838/25838 [==============================] - 24s 914us/step - loss: 0.4800 - accuracy: 0.8398 - val_loss: 1.5902 - val_accuracy: 0.6319
#
# Epoch 00072: val_loss did not improve from 1.14191
# Epoch 73/100
# 25838/25838 [==============================] - 24s 916us/step - loss: 0.4656 - accuracy: 0.8465 - val_loss: 1.7190 - val_accuracy: 0.6389
#
# Epoch 00073: val_loss did not improve from 1.14191
# Epoch 74/100
# 25838/25838 [==============================] - 24s 914us/step - loss: 0.4500 - accuracy: 0.8526 - val_loss: 1.6300 - val_accuracy: 0.6259
#
# Epoch 00074: val_loss did not improve from 1.14191
# Epoch 75/100
# 25838/25838 [==============================] - 24s 913us/step - loss: 0.4500 - accuracy: 0.8540 - val_loss: 1.6138 - val_accuracy: 0.6299
#
# Epoch 00075: val_loss did not improve from 1.14191
# Epoch 76/100
# 25838/25838 [==============================] - 24s 918us/step - loss: 0.4397 - accuracy: 0.8573 - val_loss: 1.6439 - val_accuracy: 0.6285
#
# Epoch 00076: val_loss did not improve from 1.14191
# Epoch 77/100
# 25838/25838 [==============================] - 24s 914us/step - loss: 0.4269 - accuracy: 0.8606 - val_loss: 1.6484 - val_accuracy: 0.6294
#
# Epoch 00077: val_loss did not improve from 1.14191
# Epoch 78/100
# 25838/25838 [==============================] - 24s 916us/step - loss: 0.4167 - accuracy: 0.8652 - val_loss: 1.7701 - val_accuracy: 0.6319
#
# Epoch 00078: val_loss did not improve from 1.14191
# Epoch 79/100
# 25838/25838 [==============================] - 24s 913us/step - loss: 0.4088 - accuracy: 0.8679 - val_loss: 1.7692 - val_accuracy: 0.6348
#
# Epoch 00079: val_loss did not improve from 1.14191
# Epoch 80/100
# 25838/25838 [==============================] - 24s 915us/step - loss: 0.3938 - accuracy: 0.8728 - val_loss: 1.8628 - val_accuracy: 0.6331
#
# Epoch 00080: val_loss did not improve from 1.14191
# Epoch 81/100
# 25838/25838 [==============================] - 24s 913us/step - loss: 0.3907 - accuracy: 0.8760 - val_loss: 1.8166 - val_accuracy: 0.6344
#
# Epoch 00081: val_loss did not improve from 1.14191
# Epoch 82/100
# 25838/25838 [==============================] - 24s 913us/step - loss: 0.3823 - accuracy: 0.8763 - val_loss: 1.8747 - val_accuracy: 0.6283
#
# Epoch 00082: val_loss did not improve from 1.14191
# Epoch 83/100
# 25838/25838 [==============================] - 24s 916us/step - loss: 0.3872 - accuracy: 0.8755 - val_loss: 1.8308 - val_accuracy: 0.6353
#
# Epoch 00083: val_loss did not improve from 1.14191
# Epoch 84/100
# 25838/25838 [==============================] - 24s 914us/step - loss: 0.3746 - accuracy: 0.8804 - val_loss: 1.8700 - val_accuracy: 0.6339
#
# Epoch 00084: val_loss did not improve from 1.14191
# Epoch 85/100
# 25838/25838 [==============================] - 24s 915us/step - loss: 0.3643 - accuracy: 0.8846 - val_loss: 1.8751 - val_accuracy: 0.6330
#
# Epoch 00085: val_loss did not improve from 1.14191
# Epoch 86/100
# 25838/25838 [==============================] - 24s 915us/step - loss: 0.3592 - accuracy: 0.8879 - val_loss: 1.9175 - val_accuracy: 0.6333
#
# Epoch 00086: val_loss did not improve from 1.14191
# Epoch 87/100
# 25838/25838 [==============================] - 24s 915us/step - loss: 0.3568 - accuracy: 0.8874 - val_loss: 1.9445 - val_accuracy: 0.6296
#
# Epoch 00087: val_loss did not improve from 1.14191
# Epoch 88/100
# 25838/25838 [==============================] - 24s 914us/step - loss: 0.3470 - accuracy: 0.8907 - val_loss: 1.9078 - val_accuracy: 0.6322
#
# Epoch 00088: val_loss did not improve from 1.14191
# Epoch 89/100
# 25838/25838 [==============================] - 24s 916us/step - loss: 0.3399 - accuracy: 0.8931 - val_loss: 1.9916 - val_accuracy: 0.6333
#
# Epoch 00089: val_loss did not improve from 1.14191
# Epoch 90/100
# 25838/25838 [==============================] - 24s 916us/step - loss: 0.3466 - accuracy: 0.8924 - val_loss: 1.9030 - val_accuracy: 0.6342
#
# Epoch 00090: val_loss did not improve from 1.14191
# Epoch 91/100
# 25838/25838 [==============================] - 24s 914us/step - loss: 0.3290 - accuracy: 0.8950 - val_loss: 1.9441 - val_accuracy: 0.6327
#
# Epoch 00091: val_loss did not improve from 1.14191
# Epoch 92/100
# 25838/25838 [==============================] - 24s 913us/step - loss: 0.3169 - accuracy: 0.9005 - val_loss: 1.9774 - val_accuracy: 0.6347
#
# Epoch 00092: val_loss did not improve from 1.14191
# Epoch 93/100
# 25838/25838 [==============================] - 24s 913us/step - loss: 0.3153 - accuracy: 0.9012 - val_loss: 1.9994 - val_accuracy: 0.6334
#
# Epoch 00093: val_loss did not improve from 1.14191
# Epoch 94/100
# 25838/25838 [==============================] - 24s 913us/step - loss: 0.3180 - accuracy: 0.8991 - val_loss: 2.0252 - val_accuracy: 0.6303
#
# Epoch 00094: val_loss did not improve from 1.14191
# Epoch 95/100
# 25838/25838 [==============================] - 24s 913us/step - loss: 0.3099 - accuracy: 0.9029 - val_loss: 2.1550 - val_accuracy: 0.6367
#
# Epoch 00095: val_loss did not improve from 1.14191
# Epoch 96/100
# 25838/25838 [==============================] - 24s 913us/step - loss: 0.3039 - accuracy: 0.9045 - val_loss: 2.1777 - val_accuracy: 0.6361
#
# Epoch 00096: val_loss did not improve from 1.14191
# Epoch 97/100
# 25838/25838 [==============================] - 24s 914us/step - loss: 0.3024 - accuracy: 0.9058 - val_loss: 2.1515 - val_accuracy: 0.6367
#
# Epoch 00097: val_loss did not improve from 1.14191
# Epoch 98/100
# 25838/25838 [==============================] - 24s 914us/step - loss: 0.2982 - accuracy: 0.9084 - val_loss: 2.1801 - val_accuracy: 0.6362
#
# Epoch 00098: val_loss did not improve from 1.14191
# Epoch 99/100
# 25838/25838 [==============================] - 24s 915us/step - loss: 0.2886 - accuracy: 0.9116 - val_loss: 2.2274 - val_accuracy: 0.6395
#
# Epoch 00099: val_loss did not improve from 1.14191
# Epoch 100/100
# 25838/25838 [==============================] - 24s 914us/step - loss: 0.2868 - accuracy: 0.9101 - val_loss: 2.2793 - val_accuracy: 0.6382
#
# Epoch 00100: val_loss did not improve from 1.14191

# %%
predicted_test_labels = np.argmax(model.predict(test_data), axis=1)
test_labels = np.argmax(test_labels, axis=1)
print ("Accuracy score = ", accuracy_score(test_labels, predicted_test_labels))
# Out:
# Accuracy score =  0.636110337141265

# %%
print("Model accuracy  = ",max(model_info.history['accuracy']))
print("Validation accuracy  = ",max(model_info.history['val_accuracy']))
# Out:
# Model accuracy  =  0.91156435
# Validation accuracy  =  0.6394736766815186

# %%
import matplotlib.pyplot as plt
plt.plot(model_info.history['accuracy'])
plt.plot(model_info.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %%
import matplotlib.pyplot as plt
plt.plot(model_info.history['loss'])
plt.plot(model_info.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper center')
plt.show()

# %% [markdown]
# ###  Save the model.

# %%
from keras.models import model_from_json
model_json = model.to_json()
with open("/content/gdrive/My Drive/Colab Notebooks/fer2/model.json", "w") as json_file:
    json_file.write(model_json)
# serialize weights to HDF5
model.save_weights("/content/gdrive/My Drive/Colab Notebooks/fer2/model.h5")
print("Saved model to disk")
# Out:
# Saved model to disk
